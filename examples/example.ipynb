# %%
import xmlpydict

# %%
xmlpydict.parse("<package><xmlpydict language = 'python'/></package>")
# Out:
# {'package': {'xmlpydict': {'@language': 'python'}}}

# %%
xmlpydict.parse("<person name='Matthew'>Hello!</person>")
# Out:
# {'person': {'@name': 'Matthew', '#text': 'Hello!'}}

# %%
help(xmlpydict)
# Out:
# Help on package xmlpydict:
#
# NAME
#     xmlpydict
#
# PACKAGE CONTENTS
#
#
# FUNCTIONS
#     parse(xml_content, attr_prefix: str = '@', cdata_key: str = '#text') -> dict
#         Parse XML content into a python dictionary.
#
#         Args:
#             xml_content: The XML content to be parsed.
#             attr_prefix: The prefix to use for attributes in the resulting dictionary.
#             cdata_key: The key to use for character data in the resulting dictionary.
#
#         Returns:
#             A dictionary representation of the XML content.
#
#     parse_file(file_path, attr_prefix: str = '@', cdata_key: str = '#text') -> dict
#         Parse an XML file into a python dictionary.
#
#         Args:
#             file_path: The path to the XML file to be parsed.
#             attr_prefix: The prefix to use for attributes in the resulting dictionary.
#             cdata_key: The key to use for character data in the resulting dictionary.
#
#         Returns:
#             A dictionary representation of the XML file content.
#
# FILE
#     c:\users\matth\appdata\local\programs\python\python313\lib\site-packages\xmlpydict\__init__.py

# %%
test_string = """
<svg version="1.1"
     width="300" height="200"
     xmlns="http://www.w3.org/2000/svg">
  <rect width="100%" height="100%" fill="red" />
  <circle cx="150" cy="100" r="80" fill="green" />
  <text x="150" y="125" font-size="60" text-anchor="middle" fill="white">SVG</text>
</svg>
"""

# %%
xmlpydict.parse(test_string)
# Out:
# {'svg': {'@version': '1.1',
#   '@width': '300',
#   '@height': '200',
#   '@xmlns': 'http://www.w3.org/2000/svg',
#   'rect': {'@width': '100%', '@height': '100%', '@fill': 'red'},
#   'circle': {'@cx': '150', '@cy': '100', '@r': '80', '@fill': 'green'},
#   'text': {'@x': '150',
#    '@y': '125',
#    '@font-size': '60',
#    '@text-anchor': 'middle',
#    '@fill': 'white',
#    '#text': 'SVG'}}}
